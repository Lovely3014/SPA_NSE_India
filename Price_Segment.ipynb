# %% [markdown]
# # Price segment for sector performance

# %%
df["Price_change"] = df.Close.pct_change() * 100
df
# Out:
#             Date         Open         High          Low        Close  \
# 0     2024-01-01  3790.000000  3832.000000  3773.000000  3811.100098
# 1     2024-01-02  3811.100098  3811.100098  3767.250000  3783.199951
# 2     2024-01-03  3767.000000  3771.850098  3687.050049  3691.750000
# 3     2024-01-04  3701.750000  3719.000000  3651.000000  3666.800049
# 4     2024-01-05  3675.000000  3747.750000  3674.850098  3737.899902
# ...          ...          ...          ...          ...          ...
# 10813 2024-09-05   654.000000   684.000000   653.700012   664.500000
# 10814 2024-09-06   667.799988   679.849976   657.099976   661.849976
# 10815 2024-09-09   665.750000   677.900024   664.000000   672.750000
# 10816 2024-09-10   677.000000   684.000000   675.500000   678.900024
# 10817 2024-09-11   681.000000   683.000000   674.049988   680.500000
#
#          Adj Close   Volume Symbol     Category  Price_change
# 0      3757.422119   825907    TCS  IT_industry           NaN
# 1      3729.915039  1344068    TCS  IT_industry     -0.732076
# 2      3639.753174  1803075    TCS  IT_industry     -2.417265
# 3      3615.154541  3598144    TCS  IT_industry     -0.675830
# 4      3685.252930  1963127    TCS  IT_industry      1.939016
# ...            ...      ...    ...          ...           ...
# 10813   664.500000  3457002  RITES     Railways      2.167893
# 10814   661.849976  1482454  RITES     Railways     -0.398800
# 10815   672.750000  1991325  RITES     Railways      1.646903
# 10816   678.900024   624747  RITES     Railways      0.914162
# 10817   680.500000   704295  RITES     Railways      0.235672
#
# [10818 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# Symbol          0
# Category        0
# Price_change    1
# dtype: int64

# %%
df.Price_change.fillna(0,inplace=True)

# %%
df
# Out:
#             Date         Open         High          Low        Close  \
# 0     2024-01-01  3790.000000  3832.000000  3773.000000  3811.100098
# 1     2024-01-02  3811.100098  3811.100098  3767.250000  3783.199951
# 2     2024-01-03  3767.000000  3771.850098  3687.050049  3691.750000
# 3     2024-01-04  3701.750000  3719.000000  3651.000000  3666.800049
# 4     2024-01-05  3675.000000  3747.750000  3674.850098  3737.899902
# ...          ...          ...          ...          ...          ...
# 10813 2024-09-05   654.000000   684.000000   653.700012   664.500000
# 10814 2024-09-06   667.799988   679.849976   657.099976   661.849976
# 10815 2024-09-09   665.750000   677.900024   664.000000   672.750000
# 10816 2024-09-10   677.000000   684.000000   675.500000   678.900024
# 10817 2024-09-11   681.000000   683.000000   674.049988   680.500000
#
#          Adj Close   Volume Symbol     Category  Price_change
# 0      3757.422119   825907    TCS  IT_industry      0.000000
# 1      3729.915039  1344068    TCS  IT_industry     -0.732076
# 2      3639.753174  1803075    TCS  IT_industry     -2.417265
# 3      3615.154541  3598144    TCS  IT_industry     -0.675830
# 4      3685.252930  1963127    TCS  IT_industry      1.939016
# ...            ...      ...    ...          ...           ...
# 10813   664.500000  3457002  RITES     Railways      2.167893
# 10814   661.849976  1482454  RITES     Railways     -0.398800
# 10815   672.750000  1991325  RITES     Railways      1.646903
# 10816   678.900024   624747  RITES     Railways      0.914162
# 10817   680.500000   704295  RITES     Railways      0.235672
#
# [10818 rows x 10 columns]

# %% [markdown]
# # Volumn and price correlation analysis

# %%
df_num = ( df.select_dtypes(include=['number']))
corr_matrix = df_num.corr()
corr_matrix
# Out:
#                   Open      High       Low     Close  Adj Close    Volume  \
# Open          1.000000  0.999729  0.999782  0.999585   0.999522 -0.268258
# High          0.999729  1.000000  0.999649  0.999833   0.999766 -0.267634
# Low           0.999782  0.999649  1.000000  0.999783   0.999730 -0.268473
# Close         0.999585  0.999833  0.999783  1.000000   0.999942 -0.267879
# Adj Close     0.999522  0.999766  0.999730  0.999942   1.000000 -0.267742
# Volume       -0.268258 -0.267634 -0.268473 -0.267879  -0.267742  1.000000
# Price_change  0.020368  0.021013  0.021287  0.021691   0.021548 -0.000015
#
#               Price_change
# Open              0.020368
# High              0.021013
# Low               0.021287
# Close             0.021691
# Adj Close         0.021548
# Volume           -0.000015
# Price_change      1.000000

# %%
print(df.Symbol.unique())
d=input('Enter Symbol: ')
z=df[df.Symbol == d]
plt.figure(figsize=(20,6))
sb.lineplot(x=z.Date,y=z.Price_change,color="red")
plt.xticks(rotation = 90)
plt.show()
# Out:
# ['TCS' 'WIPRO' 'OFSS' 'KPITTECH' 'INFY' 'HCLTECH' 'LTIM' 'TECHM'
#  'PERSISTENT' 'MPHASIS' 'TATAELXSI' 'COFORGE' 'CYIENT' 'AFFLE'
#  'ZENSERTECH' 'BAYERCROP' 'UPL LIMITED' 'ESCORTS' 'PIIND' 'BASF'
#  'JSWENERGY' 'RELIANCE' 'NTPC' 'ONGC' 'ADANIGREEN' 'APOLLOHOSP'
#  'ARTEMISMED' 'ASTERDM' 'LALPATHLAB' 'FORTIS' 'HINDUNILVR' 'ITC'
#  'NESTLEIND' 'BRITANNIA' 'MARICO' 'INFOSYS' 'HAL' 'BDL' 'BEL' 'MDL' 'BEML'
#  'HDFCBank' 'ICICIBANK' 'BAJFINANCE' 'SBIN' 'AXISBANK' 'IRFC' 'IRCTC'
#  'RVNL' 'BHEL' 'TITAGARH' 'KERNEX' 'NCC' 'DCW' 'IRCON' 'RAILTEL' 'CONCOR'
#  'RITES']
# Enter Symbol: ICICIBANK

# %% [markdown]
# # Stock Volatility Analysis

# %%
df["Daily_range"] = df.High - df.Low
df
# Out:
#             Date         Open         High          Low        Close  \
# 0     2024-01-01  3790.000000  3832.000000  3773.000000  3811.100098
# 1     2024-01-02  3811.100098  3811.100098  3767.250000  3783.199951
# 2     2024-01-03  3767.000000  3771.850098  3687.050049  3691.750000
# 3     2024-01-04  3701.750000  3719.000000  3651.000000  3666.800049
# 4     2024-01-05  3675.000000  3747.750000  3674.850098  3737.899902
# ...          ...          ...          ...          ...          ...
# 10813 2024-09-05   654.000000   684.000000   653.700012   664.500000
# 10814 2024-09-06   667.799988   679.849976   657.099976   661.849976
# 10815 2024-09-09   665.750000   677.900024   664.000000   672.750000
# 10816 2024-09-10   677.000000   684.000000   675.500000   678.900024
# 10817 2024-09-11   681.000000   683.000000   674.049988   680.500000
#
#          Adj Close   Volume Symbol     Category  Price_change  Daily_range
# 0      3757.422119   825907    TCS  IT_industry      0.000000    59.000000
# 1      3729.915039  1344068    TCS  IT_industry     -0.732076    43.850098
# 2      3639.753174  1803075    TCS  IT_industry     -2.417265    84.800049
# 3      3615.154541  3598144    TCS  IT_industry     -0.675830    68.000000
# 4      3685.252930  1963127    TCS  IT_industry      1.939016    72.899902
# ...            ...      ...    ...          ...           ...          ...
# 10813   664.500000  3457002  RITES     Railways      2.167893    30.299988
# 10814   661.849976  1482454  RITES     Railways     -0.398800    22.750000
# 10815   672.750000  1991325  RITES     Railways      1.646903    13.900024
# 10816   678.900024   624747  RITES     Railways      0.914162     8.500000
# 10817   680.500000   704295  RITES     Railways      0.235672     8.950012
#
# [10818 rows x 11 columns]

# %%
df["Volatility"] = df.Close.rolling(window = 20).std()
df
# Out:
#             Date         Open         High          Low        Close  \
# 0     2024-01-01  3790.000000  3832.000000  3773.000000  3811.100098
# 1     2024-01-02  3811.100098  3811.100098  3767.250000  3783.199951
# 2     2024-01-03  3767.000000  3771.850098  3687.050049  3691.750000
# 3     2024-01-04  3701.750000  3719.000000  3651.000000  3666.800049
# 4     2024-01-05  3675.000000  3747.750000  3674.850098  3737.899902
# ...          ...          ...          ...          ...          ...
# 10813 2024-09-05   654.000000   684.000000   653.700012   664.500000
# 10814 2024-09-06   667.799988   679.849976   657.099976   661.849976
# 10815 2024-09-09   665.750000   677.900024   664.000000   672.750000
# 10816 2024-09-10   677.000000   684.000000   675.500000   678.900024
# 10817 2024-09-11   681.000000   683.000000   674.049988   680.500000
#
#          Adj Close   Volume Symbol     Category  Price_change  Daily_range  \
# 0      3757.422119   825907    TCS  IT_industry      0.000000    59.000000
# 1      3729.915039  1344068    TCS  IT_industry     -0.732076    43.850098
# 2      3639.753174  1803075    TCS  IT_industry     -2.417265    84.800049
# 3      3615.154541  3598144    TCS  IT_industry     -0.675830    68.000000
# 4      3685.252930  1963127    TCS  IT_industry      1.939016    72.899902
# ...            ...      ...    ...          ...           ...          ...
# 10813   664.500000  3457002  RITES     Railways      2.167893    30.299988
# 10814   661.849976  1482454  RITES     Railways     -0.398800    22.750000
# 10815   672.750000  1991325  RITES     Railways      1.646903    13.900024
# 10816   678.900024   624747  RITES     Railways      0.914162     8.500000
# 10817   680.500000   704295  RITES     Railways      0.235672     8.950012
#
#        Volatility
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 10813   11.684855
# 10814    9.423177
# 10815    7.909720
# 10816    8.297895
# 10817    9.388048
#
# [10818 rows x 12 columns]

# %%
df.Volatility.fillna(0,inplace=True)
df
# Out:
#             Date         Open         High          Low        Close  \
# 0     2024-01-01  3790.000000  3832.000000  3773.000000  3811.100098
# 1     2024-01-02  3811.100098  3811.100098  3767.250000  3783.199951
# 2     2024-01-03  3767.000000  3771.850098  3687.050049  3691.750000
# 3     2024-01-04  3701.750000  3719.000000  3651.000000  3666.800049
# 4     2024-01-05  3675.000000  3747.750000  3674.850098  3737.899902
# ...          ...          ...          ...          ...          ...
# 10813 2024-09-05   654.000000   684.000000   653.700012   664.500000
# 10814 2024-09-06   667.799988   679.849976   657.099976   661.849976
# 10815 2024-09-09   665.750000   677.900024   664.000000   672.750000
# 10816 2024-09-10   677.000000   684.000000   675.500000   678.900024
# 10817 2024-09-11   681.000000   683.000000   674.049988   680.500000
#
#          Adj Close   Volume Symbol     Category  Price_change  Daily_range  \
# 0      3757.422119   825907    TCS  IT_industry      0.000000    59.000000
# 1      3729.915039  1344068    TCS  IT_industry     -0.732076    43.850098
# 2      3639.753174  1803075    TCS  IT_industry     -2.417265    84.800049
# 3      3615.154541  3598144    TCS  IT_industry     -0.675830    68.000000
# 4      3685.252930  1963127    TCS  IT_industry      1.939016    72.899902
# ...            ...      ...    ...          ...           ...          ...
# 10813   664.500000  3457002  RITES     Railways      2.167893    30.299988
# 10814   661.849976  1482454  RITES     Railways     -0.398800    22.750000
# 10815   672.750000  1991325  RITES     Railways      1.646903    13.900024
# 10816   678.900024   624747  RITES     Railways      0.914162     8.500000
# 10817   680.500000   704295  RITES     Railways      0.235672     8.950012
#
#        Volatility
# 0        0.000000
# 1        0.000000
# 2        0.000000
# 3        0.000000
# 4        0.000000
# ...           ...
# 10813   11.684855
# 10814    9.423177
# 10815    7.909720
# 10816    8.297895
# 10817    9.388048
#
# [10818 rows x 12 columns]

# %%
df_nums = ( df.select_dtypes(include=['number']))
cor_matrix = df_nums.corr()
cor_matrix
# Out:
#                   Open      High       Low     Close  Adj Close    Volume  \
# Open          1.000000  0.999729  0.999782  0.999585   0.999522 -0.268258
# High          0.999729  1.000000  0.999649  0.999833   0.999766 -0.267634
# Low           0.999782  0.999649  1.000000  0.999783   0.999730 -0.268473
# Close         0.999585  0.999833  0.999783  1.000000   0.999942 -0.267879
# Adj Close     0.999522  0.999766  0.999730  0.999942   1.000000 -0.267742
# Volume       -0.268258 -0.267634 -0.268473 -0.267879  -0.267742  1.000000
# Price_change  0.020368  0.021013  0.021287  0.021691   0.021548 -0.000015
# Daily_range   0.719161  0.729764  0.711402  0.721880   0.721487 -0.171235
# Volatility    0.205863  0.206406  0.205071  0.205520   0.204331 -0.064795
#
#               Price_change  Daily_range  Volatility
# Open              0.020368     0.719161    0.205863
# High              0.021013     0.729764    0.206406
# Low               0.021287     0.711402    0.205071
# Close             0.021691     0.721880    0.205520
# Adj Close         0.021548     0.721487    0.204331
# Volume           -0.000015    -0.171235   -0.064795
# Price_change      1.000000     0.008059    0.022296
# Daily_range       0.008059     1.000000    0.183230
# Volatility        0.022296     0.183230    1.000000

# %%
print(df.Symbol.unique())
h=input('Enter Symbol: ')
j=df[df.Symbol == h]
plt.figure(figsize=(20,6))
sb.lineplot(x=j.Date,y=j.Volatility,color="red")
plt.xticks(rotation = 90)
plt.show()
# Out:
# ['TCS' 'WIPRO' 'OFSS' 'KPITTECH' 'INFY' 'HCLTECH' 'LTIM' 'TECHM'
#  'PERSISTENT' 'MPHASIS' 'TATAELXSI' 'COFORGE' 'CYIENT' 'AFFLE'
#  'ZENSERTECH' 'BAYERCROP' 'UPL LIMITED' 'ESCORTS' 'PIIND' 'BASF'
#  'JSWENERGY' 'RELIANCE' 'NTPC' 'ONGC' 'ADANIGREEN' 'APOLLOHOSP'
#  'ARTEMISMED' 'ASTERDM' 'LALPATHLAB' 'FORTIS' 'HINDUNILVR' 'ITC'
#  'NESTLEIND' 'BRITANNIA' 'MARICO' 'INFOSYS' 'HAL' 'BDL' 'BEL' 'MDL' 'BEML'
#  'HDFCBank' 'ICICIBANK' 'BAJFINANCE' 'SBIN' 'AXISBANK' 'IRFC' 'IRCTC'
#  'RVNL' 'BHEL' 'TITAGARH' 'KERNEX' 'NCC' 'DCW' 'IRCON' 'RAILTEL' 'CONCOR'
#  'RITES']
# Enter Symbol: ICICIBANK
